# %% [markdown]
# # 03_tensorflow_cnn

# %% [markdown]
# - Fashion MNIST Example -

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import fashion_mnist

(xtr, ytr), (xt, yt) = fashion_mnist.load_data()
#fashion_mnist data load

print(xtr.shape)
print(ytr.shape)
print()
print(xt.shape)
print(yt.shape)
print()
print(ytr)
print(yt)
#28*28 크기의 이미지 데이터
#학습/ 테스트 데이터 수 = 60000 / 10000
#0~9 의 숫자로 정답이 표기돼있음.
#티셔츠/탑 0, 트라우져 1, 풀오버 2, 드레스 3, 코트 4, 샌들 5, 셔츠 6, 스니커즈 7, 가방 8, 앵클 부츠 9
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 2s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# (60000, 28, 28)
# (60000,)
#
# (10000, 28, 28)
# (10000,)
#
# [9 0 0 ... 3 0 5]
# [9 2 1 ... 8 1 5]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize = (6,6))

for idx in range(25):
#25 개의 이미지 출력

    plt.subplot(5,5, idx + 1)
    #5행 5열
    plt.imshow(xtr[idx], cmap = 'gray')
    plt.axis('off')
    
plt.show()

# %%
#데이터 전처리(minmax 정규화)

xtr = (xtr - 0.0) / (255.0 - 0.0)
xt = (xt - 0.0) / (255.0 - 0.0)
#max = 255.0, min = 0.0

# %%
#모델링 및 컴파일

md = tf.keras.Sequential()

md.add(tf.keras.layers.Flatten(input_shape = (28, 28)))
#28*28 크기 2차원 이미지를 784 개의 1차원 벡터로 변환

md.add(tf.keras.layers.Dense(100, activation = 'relu'))

md.add(tf.keras.layers.Dense(10, activation = 'softmax'))

md.compile(optimizer = tf.keras.optimizers.Adam(learning_rate = 1e-3),\
          loss = 'sparse_categorical_crossentropy', metrics = ['accuracy'])
#정답 데이터를 원핫 인코딩 처리하지 않아서 sparse_crossentropy 손실 함수 사용

md.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 100)               78500
#
#  dense_1 (Dense)             (None, 10)                1010
#
# =================================================================
# Total params: 79,510
# Trainable params: 79,510
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 학습

hist = md.fit(xtr, ytr, epochs = 30, validation_split = 0.3)
#데이터 중 30%의 검증용 데이터셋 생성(모델의 overfitting 을 monitoring)
# Out:
# Epoch 1/30
# 1313/1313 [==============================] - 7s 4ms/step - loss: 0.5418 - accuracy: 0.8124 - val_loss: 0.4477 - val_accuracy: 0.8398
# Epoch 2/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.4032 - accuracy: 0.8556 - val_loss: 0.4007 - val_accuracy: 0.8539
# Epoch 3/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3615 - accuracy: 0.8696 - val_loss: 0.3656 - val_accuracy: 0.8689
# Epoch 4/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3327 - accuracy: 0.8785 - val_loss: 0.3982 - val_accuracy: 0.8493
# Epoch 5/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.3158 - accuracy: 0.8845 - val_loss: 0.3626 - val_accuracy: 0.8688
# Epoch 6/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2948 - accuracy: 0.8917 - val_loss: 0.3627 - val_accuracy: 0.8710
# Epoch 7/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2829 - accuracy: 0.8956 - val_loss: 0.3431 - val_accuracy: 0.8776
# Epoch 8/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2694 - accuracy: 0.9002 - val_loss: 0.3339 - val_accuracy: 0.8786
# Epoch 9/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2628 - accuracy: 0.9027 - val_loss: 0.3461 - val_accuracy: 0.8803
# Epoch 10/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2509 - accuracy: 0.9065 - val_loss: 0.3342 - val_accuracy: 0.8804
# Epoch 11/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2410 - accuracy: 0.9114 - val_loss: 0.3390 - val_accuracy: 0.8820
# Epoch 12/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.2369 - accuracy: 0.9114 - val_loss: 0.3300 - val_accuracy: 0.8873
# Epoch 13/30
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.2286 - accuracy: 0.9143 - val_loss: 0.3406 - val_accuracy: 0.8816
# Epoch 14/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2190 - accuracy: 0.9182 - val_loss: 0.3228 - val_accuracy: 0.8899
# Epoch 15/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2135 - accuracy: 0.9212 - val_loss: 0.3251 - val_accuracy: 0.8862
# Epoch 16/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2078 - accuracy: 0.9212 - val_loss: 0.3339 - val_accuracy: 0.8885
# Epoch 17/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.2016 - accuracy: 0.9241 - val_loss: 0.3408 - val_accuracy: 0.8862
# Epoch 18/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1953 - accuracy: 0.9267 - val_loss: 0.3275 - val_accuracy: 0.8925
# Epoch 19/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1915 - accuracy: 0.9273 - val_loss: 0.3415 - val_accuracy: 0.8898
# Epoch 20/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1851 - accuracy: 0.9310 - val_loss: 0.3411 - val_accuracy: 0.8888
# Epoch 21/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1813 - accuracy: 0.9325 - val_loss: 0.3361 - val_accuracy: 0.8887
# Epoch 22/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1754 - accuracy: 0.9335 - val_loss: 0.3495 - val_accuracy: 0.8881
# Epoch 23/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1738 - accuracy: 0.9346 - val_loss: 0.3462 - val_accuracy: 0.8893
# Epoch 24/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1664 - accuracy: 0.9379 - val_loss: 0.3551 - val_accuracy: 0.8899
# Epoch 25/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1626 - accuracy: 0.9387 - val_loss: 0.3502 - val_accuracy: 0.8923
# Epoch 26/30
# 1313/1313 [==============================] - 5s 3ms/step - loss: 0.1587 - accuracy: 0.9397 - val_loss: 0.3750 - val_accuracy: 0.8864
# Epoch 27/30
# 1313/1313 [==============================] - 5s 4ms/step - loss: 0.1540 - accuracy: 0.9427 - val_loss: 0.3742 - val_accuracy: 0.8875
# Epoch 28/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1526 - accuracy: 0.9434 - val_loss: 0.3777 - val_accuracy: 0.8886
# Epoch 29/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1485 - accuracy: 0.9451 - val_loss: 0.3772 - val_accuracy: 0.8887
# Epoch 30/30
# 1313/1313 [==============================] - 4s 3ms/step - loss: 0.1458 - accuracy: 0.9446 - val_loss: 0.3723 - val_accuracy: 0.8918

# %%
#모델 정확도 평가

md.evaluate(xt, yt)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.4104 - accuracy: 0.8838
# [0.41044560074806213, 0.8838000297546387]

# %% [markdown]
# *fashion_mnist 테스트 데이터에 대해 약 88% 의 모델 정확도를 확인할 수 있었습니다.

# %%
#손실 시각화

plt.title('Loss')
plt.xlabel('epochs')
plt.ylabel('loss')
plt.grid()

plt.plot(hist.history['loss'], label = 'train loss')
plt.plot(hist.history['val_loss'], label = 'validation loss')

plt.legend(loc = 'best')

plt.show()

# %%
#정확도 시각화

plt.title('Accuracy')
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.grid()

plt.plot(hist.history['accuracy'], label = 'train accuracy')
plt.plot(hist.history['val_accuracy'], label = 'validation accuracy')

plt.legend(loc = 'best')

plt.show()

# %% [markdown]
# *약 87% accuracy 부근에서 train 과 validation 데이터의 accuracy 격차가 많이 벌어짐.

# %% [markdown]
# *해당 구간부터 모델의 overfitting 이 일어나는 것을 알 수 있습니다.

# %%
#혼동 행렬

from sklearn.metrics import confusion_matrix
import seaborn as sns

plt.figure(figsize = (6, 6))

pred = md.predict(xt)
#테스트 데이터 예측

cm = confusion_matrix(yt, 
                      np.argmax(pred, axis = -1))

sns.heatmap(cm, annot = True, fmt = 'd')
#혼동행렬 히트맵으로 시각화

plt.show()
# Out:
# 313/313 [==============================] - 1s 2ms/step

# %%
for i in range(10):
    
    print(('label = %d\t(%d/%d)\taccuracy = %.3f') % 
          (i, np.max(cm[i]), np.sum(cm[i]), 
           np.max(cm[i])/np.sum(cm[i])))
# Out:
# label = 0	(849/1000)	accuracy = 0.849
# label = 1	(977/1000)	accuracy = 0.977
# label = 2	(843/1000)	accuracy = 0.843
# label = 3	(887/1000)	accuracy = 0.887
# label = 4	(783/1000)	accuracy = 0.783
# label = 5	(960/1000)	accuracy = 0.960
# label = 6	(660/1000)	accuracy = 0.660
# label = 7	(960/1000)	accuracy = 0.960
# label = 8	(961/1000)	accuracy = 0.961
# label = 9	(958/1000)	accuracy = 0.958

# %% [markdown]
# *생성한 모델에서 label 1(트라우져) 정확도 약 98% 로 가장 높은 정확도를 보여줬습니다.

# %% [markdown]
# *생성한 모델에서 label 6(셔츠) 정확도 약 66% 로 가장 낮은 정확도를 보여줬습니다.

# %% [markdown]
# - Convolution(컨볼루션, 합성곱) -

# %% [markdown]
# *데이터 관점에서 곱셈 연산 - 원본 데이터 or 입력 데이터에 변화(variation) 을 주어 출력 데이터를 생성.

# %% [markdown]
# *데이터 관점에서 덧셈 연산 - 데이터의 평균(mean) 을 구한다는 의미를 내포.

# %% [markdown]
# *convolution - 시간의 흐름에 따라 데이터 g(x) 가 이동하면서,

# %% [markdown]
# 입력 데이터 f(x) 를 평균적으로 얼마나 변화시키는지(평균적으로 얼마나 변하는지) 나타내는 개념.

# %% [markdown]
# NN(Neural network) vs. CNN(Convolution -)

# %% [markdown]
# *NN 에서 은닉층 역할을 CNN 에서 여러 개의 convolution 층, 그리고 출력층 앞의 완전 연결층(flatten) 으로 대신 수행.

# %% [markdown]
# conv - 입력 데이터와 다양한 필터(가중치 집합체) 와의 convolution 연산을 통해 입력 데이터의 feature 추출하는 역할 수행.

# %% [markdown]
# pooling - 입력 정보를 max/min/mean 값 등으로 압축하여 데이터 연산량을 줄여주는 역할 수행 후, 다음 층으로 넘겨줌.

# %% [markdown]
# (일반적으로 max pooling 을 가장 많이 사용)

# %% [markdown]
# convolution 연산 - 필터를 일정간격(stride) 로 이동해가면서 입력데이터와 필터 대응 원소끼리 곱한 후 모두 더해주는 연산,

# %% [markdown]
# -stride : 필터의 이동 간격

# %% [markdown]
# - 패딩(padding) : convolution 연산 전, 입력 데이터 주변을 특정값으로 채움.

# %% [markdown]
# *데이터 크기가 줄어드는 단점을 방지하기 위해 사용.

# %% [markdown]
# 연산을 통한 출력 데이터 크기 : (OH, OW), OH 행 OW 열

# %% [markdown]
# OH = (H + 2P - FH) / S + 1

# %% [markdown]
# OW = (W + 2P - FW) / S + 1

# %% [markdown]
# (H, W) - 입력데이터 크기, (FH, FW) - 필터데이터 크기, P - 패딩, S - 스트라이드

# %% [markdown]
# - CNN, MNIST / Fashion MNIST Example -

# %% [markdown]
# 이미지 분류를 위해 사용되는 일반적인 CNN 구조)

# %% [markdown]
# 특징 추출기(feature extractor) + 분류기(classifier) 결합 형태

# %% [markdown]
# 특징 추출기 - 이미지 데이터 특징을 추출하고 압축하는 역할, conv layer 와 pooling layer 의 다양한 조합으로 이루어짐.

# %% [markdown]
# 분류기 - 정답 분류하는 역할 수행, 완전연결층(dense layer) 과 dropout layer(오버피팅 방지) 로 이루어짐.

# %%
import tensorflow as tf
import numpy as np
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPool2D
from tensorflow.keras.layers import Flatten, Dense, Dropout

(xtr, ytr), (xt, yt) = mnist.load_data()
#mnist data load

xtr = xtr.reshape(-1, 28, 28, 1)
xt = xt.reshape(-1, 28, 28, 1)
#tensor 로 변환(높이, 너비, 채널 형태)

xtr = xtr.astype(np.float32)/255.0
xt = xt.astype(np.float32)/255.0
#정규화
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 2s 0us/step

# %%
#CNN Modeling example

cnn = Sequential()

cnn.add(Conv2D(input_shape = (28,28,1), kernel_size = (3, 3), filters = 32, activation = 'relu'))
cnn.add(Conv2D(kernel_size = (3, 3), filters = 64, activation = 'relu'))
cnn.add(MaxPool2D(pool_size = (2, 2)))
#네 개의 데이터로 압축 후 최대값 출력(maxpooling)

cnn.add(Dropout(0.25))
#overfitting 방지 위해 25% 비율로 data dropout

#---------------------- (윗쪽 : Feature extractor), (아래쪽 : Classifier) -----------------------------------

cnn.add(Flatten())
#3차원 텐서를 1차원 벡터로 변환

cnn.add(Dense(128, activation = 'relu'))
#은닉층

cnn.add(Dropout(0.5))

cnn.add(Dense(10, activation = 'softmax'))
#출력층

# %%
#CNN Model Compiling & training

cnn.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(),\
           metrics = ['accuracy'])

hist = cnn.fit(xtr, ytr, batch_size = 128, epochs = 100, validation_data = (xt, yt))
# Out:
# Epoch 1/100
# 469/469 [==============================] - 11s 9ms/step - loss: 0.2569 - accuracy: 0.9208 - val_loss: 0.0550 - val_accuracy: 0.9820
# Epoch 2/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0904 - accuracy: 0.9728 - val_loss: 0.0448 - val_accuracy: 0.9851
# Epoch 3/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0686 - accuracy: 0.9797 - val_loss: 0.0361 - val_accuracy: 0.9874
# Epoch 4/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0551 - accuracy: 0.9827 - val_loss: 0.0305 - val_accuracy: 0.9896
# Epoch 5/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0486 - accuracy: 0.9849 - val_loss: 0.0298 - val_accuracy: 0.9903
# Epoch 6/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0403 - accuracy: 0.9879 - val_loss: 0.0277 - val_accuracy: 0.9917
# Epoch 7/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0388 - accuracy: 0.9879 - val_loss: 0.0290 - val_accuracy: 0.9914
# Epoch 8/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0324 - accuracy: 0.9897 - val_loss: 0.0271 - val_accuracy: 0.9917
# Epoch 9/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0304 - accuracy: 0.9900 - val_loss: 0.0287 - val_accuracy: 0.9923
# Epoch 10/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0261 - accuracy: 0.9919 - val_loss: 0.0284 - val_accuracy: 0.9917
# Epoch 11/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0258 - accuracy: 0.9917 - val_loss: 0.0290 - val_accuracy: 0.9916
# Epoch 12/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.0323 - val_accuracy: 0.9916
# Epoch 13/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0221 - accuracy: 0.9928 - val_loss: 0.0306 - val_accuracy: 0.9919
# Epoch 14/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0211 - accuracy: 0.9931 - val_loss: 0.0277 - val_accuracy: 0.9927
# Epoch 15/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0190 - accuracy: 0.9937 - val_loss: 0.0312 - val_accuracy: 0.9914
# Epoch 16/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0179 - accuracy: 0.9935 - val_loss: 0.0315 - val_accuracy: 0.9917
# Epoch 17/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0168 - accuracy: 0.9942 - val_loss: 0.0317 - val_accuracy: 0.9923
# Epoch 18/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0172 - accuracy: 0.9942 - val_loss: 0.0343 - val_accuracy: 0.9912
# Epoch 19/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0157 - accuracy: 0.9948 - val_loss: 0.0331 - val_accuracy: 0.9922
# Epoch 20/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0155 - accuracy: 0.9949 - val_loss: 0.0370 - val_accuracy: 0.9916
# Epoch 21/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0138 - accuracy: 0.9952 - val_loss: 0.0326 - val_accuracy: 0.9921
# Epoch 22/100
# 469/469 [==============================] - 5s 11ms/step - loss: 0.0139 - accuracy: 0.9951 - val_loss: 0.0354 - val_accuracy: 0.9919
# Epoch 23/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0118 - accuracy: 0.9961 - val_loss: 0.0321 - val_accuracy: 0.9924
# Epoch 24/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0131 - accuracy: 0.9955 - val_loss: 0.0363 - val_accuracy: 0.9931
# Epoch 25/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0115 - accuracy: 0.9961 - val_loss: 0.0369 - val_accuracy: 0.9918
# Epoch 26/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0115 - accuracy: 0.9958 - val_loss: 0.0342 - val_accuracy: 0.9932
# Epoch 27/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0133 - accuracy: 0.9958 - val_loss: 0.0340 - val_accuracy: 0.9920
# Epoch 28/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0108 - accuracy: 0.9962 - val_loss: 0.0342 - val_accuracy: 0.9927
# Epoch 29/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0108 - accuracy: 0.9963 - val_loss: 0.0335 - val_accuracy: 0.9928
# Epoch 30/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0114 - accuracy: 0.9961 - val_loss: 0.0340 - val_accuracy: 0.9932
# Epoch 31/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0101 - accuracy: 0.9966 - val_loss: 0.0337 - val_accuracy: 0.9931
# Epoch 32/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0098 - accuracy: 0.9968 - val_loss: 0.0313 - val_accuracy: 0.9942
# Epoch 33/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0097 - accuracy: 0.9968 - val_loss: 0.0351 - val_accuracy: 0.9921
# Epoch 34/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0099 - accuracy: 0.9967 - val_loss: 0.0299 - val_accuracy: 0.9934
# Epoch 35/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0087 - accuracy: 0.9969 - val_loss: 0.0368 - val_accuracy: 0.9922
# Epoch 36/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0080 - accuracy: 0.9973 - val_loss: 0.0339 - val_accuracy: 0.9936
# Epoch 37/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0090 - accuracy: 0.9970 - val_loss: 0.0357 - val_accuracy: 0.9930
# Epoch 38/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0082 - accuracy: 0.9973 - val_loss: 0.0325 - val_accuracy: 0.9933
# Epoch 39/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0317 - val_accuracy: 0.9940
# Epoch 40/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0098 - accuracy: 0.9967 - val_loss: 0.0341 - val_accuracy: 0.9945
# Epoch 41/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0086 - accuracy: 0.9972 - val_loss: 0.0406 - val_accuracy: 0.9923
# Epoch 42/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0074 - accuracy: 0.9977 - val_loss: 0.0333 - val_accuracy: 0.9939
# Epoch 43/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0068 - accuracy: 0.9976 - val_loss: 0.0330 - val_accuracy: 0.9934
# Epoch 44/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0071 - accuracy: 0.9976 - val_loss: 0.0328 - val_accuracy: 0.9943
# Epoch 45/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0089 - accuracy: 0.9972 - val_loss: 0.0358 - val_accuracy: 0.9938
# Epoch 46/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0079 - accuracy: 0.9973 - val_loss: 0.0321 - val_accuracy: 0.9945
# Epoch 47/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0059 - accuracy: 0.9980 - val_loss: 0.0393 - val_accuracy: 0.9930
# Epoch 48/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0076 - accuracy: 0.9975 - val_loss: 0.0364 - val_accuracy: 0.9942
# Epoch 49/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0066 - accuracy: 0.9977 - val_loss: 0.0366 - val_accuracy: 0.9931
# Epoch 50/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0075 - accuracy: 0.9976 - val_loss: 0.0366 - val_accuracy: 0.9936
# Epoch 51/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0073 - accuracy: 0.9977 - val_loss: 0.0383 - val_accuracy: 0.9931
# Epoch 52/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0066 - accuracy: 0.9976 - val_loss: 0.0419 - val_accuracy: 0.9926
# Epoch 53/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.0376 - val_accuracy: 0.9934
# Epoch 54/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 0.0367 - val_accuracy: 0.9939
# Epoch 55/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.0354 - val_accuracy: 0.9940
# Epoch 56/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0078 - accuracy: 0.9973 - val_loss: 0.0373 - val_accuracy: 0.9929
# Epoch 57/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0065 - accuracy: 0.9980 - val_loss: 0.0392 - val_accuracy: 0.9936
# Epoch 58/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0077 - accuracy: 0.9974 - val_loss: 0.0364 - val_accuracy: 0.9939
# Epoch 59/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0060 - accuracy: 0.9980 - val_loss: 0.0403 - val_accuracy: 0.9931
# Epoch 60/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0064 - accuracy: 0.9980 - val_loss: 0.0386 - val_accuracy: 0.9929
# Epoch 61/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0407 - val_accuracy: 0.9932
# Epoch 62/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0428 - val_accuracy: 0.9932
# Epoch 63/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.0419 - val_accuracy: 0.9938
# Epoch 64/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0064 - accuracy: 0.9978 - val_loss: 0.0380 - val_accuracy: 0.9941
# Epoch 65/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0047 - accuracy: 0.9986 - val_loss: 0.0429 - val_accuracy: 0.9934
# Epoch 66/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0063 - accuracy: 0.9979 - val_loss: 0.0373 - val_accuracy: 0.9941
# Epoch 67/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0058 - accuracy: 0.9981 - val_loss: 0.0479 - val_accuracy: 0.9930
# Epoch 68/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0068 - accuracy: 0.9977 - val_loss: 0.0360 - val_accuracy: 0.9939
# Epoch 69/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0052 - accuracy: 0.9983 - val_loss: 0.0445 - val_accuracy: 0.9929
# Epoch 70/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0397 - val_accuracy: 0.9936
# Epoch 71/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0059 - accuracy: 0.9981 - val_loss: 0.0374 - val_accuracy: 0.9940
# Epoch 72/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0453 - val_accuracy: 0.9934
# Epoch 73/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0062 - accuracy: 0.9978 - val_loss: 0.0398 - val_accuracy: 0.9940
# Epoch 74/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0051 - accuracy: 0.9983 - val_loss: 0.0433 - val_accuracy: 0.9930
# Epoch 75/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0427 - val_accuracy: 0.9929
# Epoch 76/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0050 - accuracy: 0.9983 - val_loss: 0.0455 - val_accuracy: 0.9937
# Epoch 77/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0433 - val_accuracy: 0.9937
# Epoch 78/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0053 - accuracy: 0.9983 - val_loss: 0.0432 - val_accuracy: 0.9937
# Epoch 79/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0431 - val_accuracy: 0.9935
# Epoch 80/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0054 - accuracy: 0.9981 - val_loss: 0.0457 - val_accuracy: 0.9933
# Epoch 81/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0060 - accuracy: 0.9981 - val_loss: 0.0481 - val_accuracy: 0.9932
# Epoch 82/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0046 - accuracy: 0.9983 - val_loss: 0.0376 - val_accuracy: 0.9942
# Epoch 83/100
# 469/469 [==============================] - 5s 10ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0432 - val_accuracy: 0.9932
# Epoch 84/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0403 - val_accuracy: 0.9935
# Epoch 85/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0443 - val_accuracy: 0.9934
# Epoch 86/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0057 - accuracy: 0.9980 - val_loss: 0.0415 - val_accuracy: 0.9945
# Epoch 87/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0047 - accuracy: 0.9984 - val_loss: 0.0490 - val_accuracy: 0.9933
# Epoch 88/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0050 - accuracy: 0.9984 - val_loss: 0.0451 - val_accuracy: 0.9945
# Epoch 89/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0055 - accuracy: 0.9981 - val_loss: 0.0483 - val_accuracy: 0.9930
# Epoch 90/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0052 - accuracy: 0.9982 - val_loss: 0.0447 - val_accuracy: 0.9932
# Epoch 91/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0051 - accuracy: 0.9984 - val_loss: 0.0447 - val_accuracy: 0.9937
# Epoch 92/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0038 - accuracy: 0.9985 - val_loss: 0.0451 - val_accuracy: 0.9930
# Epoch 93/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0043 - accuracy: 0.9986 - val_loss: 0.0438 - val_accuracy: 0.9939
# Epoch 94/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0046 - accuracy: 0.9984 - val_loss: 0.0479 - val_accuracy: 0.9937
# Epoch 95/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.0454 - val_accuracy: 0.9934
# Epoch 96/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0473 - val_accuracy: 0.9937
# Epoch 97/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0045 - accuracy: 0.9987 - val_loss: 0.0461 - val_accuracy: 0.9934
# Epoch 98/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0042 - accuracy: 0.9986 - val_loss: 0.0521 - val_accuracy: 0.9935
# Epoch 99/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0055 - accuracy: 0.9984 - val_loss: 0.0480 - val_accuracy: 0.9940
# Epoch 100/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0049 - accuracy: 0.9986 - val_loss: 0.0520 - val_accuracy: 0.9938

# %%
#CNN Model 정확도 평가

cnn.evaluate(xt, yt)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.0520 - accuracy: 0.9938
# [0.05197156220674515, 0.9937999844551086]

# %%
from tensorflow.keras.datasets import fashion_mnist

(xtr, ytr), (xt, yt) = fashion_mnist.load_data()
#fashion_mnist data load

xtr = xtr.reshape(-1, 28, 28, 1)
xt = xt.reshape(-1, 28, 28, 1)

xtr = xtr.astype(np.float32)/255.0
xt = xt.astype(np.float32)/255.0

cnn = Sequential()

cnn.add(Conv2D(input_shape = (28,28,1), kernel_size = (3, 3), filters = 32, activation = 'relu'))
cnn.add(Conv2D(kernel_size = (3, 3), filters = 64, activation = 'relu'))
cnn.add(MaxPool2D(pool_size = (2, 2)))
cnn.add(Dropout(0.25))

cnn.add(Flatten())

cnn.add(Dense(128, activation = 'relu'))
cnn.add(Dropout(0.5))
cnn.add(Dense(10, activation = 'softmax'))

cnn.compile(loss = 'sparse_categorical_crossentropy', optimizer = tf.keras.optimizers.Adam(),\
           metrics = ['accuracy'])

hist = cnn.fit(xtr, ytr, batch_size = 128, epochs = 100, validation_data = (xt, yt))
# Out:
# Epoch 1/100
# 469/469 [==============================] - 5s 9ms/step - loss: 0.5205 - accuracy: 0.8165 - val_loss: 0.3293 - val_accuracy: 0.8820
# Epoch 2/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.3386 - accuracy: 0.8792 - val_loss: 0.2792 - val_accuracy: 0.8977
# Epoch 3/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2896 - accuracy: 0.8947 - val_loss: 0.2562 - val_accuracy: 0.9062
# Epoch 4/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2593 - accuracy: 0.9069 - val_loss: 0.2560 - val_accuracy: 0.9068
# Epoch 5/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2360 - accuracy: 0.9132 - val_loss: 0.2353 - val_accuracy: 0.9124
# Epoch 6/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2175 - accuracy: 0.9197 - val_loss: 0.2333 - val_accuracy: 0.9150
# Epoch 7/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.2026 - accuracy: 0.9257 - val_loss: 0.2190 - val_accuracy: 0.9228
# Epoch 8/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1872 - accuracy: 0.9300 - val_loss: 0.2183 - val_accuracy: 0.9219
# Epoch 9/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1733 - accuracy: 0.9353 - val_loss: 0.2115 - val_accuracy: 0.9232
# Epoch 10/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1631 - accuracy: 0.9392 - val_loss: 0.2131 - val_accuracy: 0.9228
# Epoch 11/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1506 - accuracy: 0.9434 - val_loss: 0.2207 - val_accuracy: 0.9242
# Epoch 12/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1449 - accuracy: 0.9450 - val_loss: 0.2341 - val_accuracy: 0.9233
# Epoch 13/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1351 - accuracy: 0.9491 - val_loss: 0.2277 - val_accuracy: 0.9271
# Epoch 14/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1272 - accuracy: 0.9510 - val_loss: 0.2278 - val_accuracy: 0.9278
# Epoch 15/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1206 - accuracy: 0.9535 - val_loss: 0.2279 - val_accuracy: 0.9299
# Epoch 16/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1134 - accuracy: 0.9561 - val_loss: 0.2339 - val_accuracy: 0.9290
# Epoch 17/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1081 - accuracy: 0.9579 - val_loss: 0.2331 - val_accuracy: 0.9295
# Epoch 18/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1045 - accuracy: 0.9606 - val_loss: 0.2315 - val_accuracy: 0.9307
# Epoch 19/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.1010 - accuracy: 0.9614 - val_loss: 0.2459 - val_accuracy: 0.9305
# Epoch 20/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0969 - accuracy: 0.9625 - val_loss: 0.2473 - val_accuracy: 0.9297
# Epoch 21/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0917 - accuracy: 0.9643 - val_loss: 0.2456 - val_accuracy: 0.9302
# Epoch 22/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0882 - accuracy: 0.9660 - val_loss: 0.2637 - val_accuracy: 0.9300
# Epoch 23/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0862 - accuracy: 0.9664 - val_loss: 0.2731 - val_accuracy: 0.9260
# Epoch 24/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0828 - accuracy: 0.9680 - val_loss: 0.2632 - val_accuracy: 0.9289
# Epoch 25/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0809 - accuracy: 0.9680 - val_loss: 0.2686 - val_accuracy: 0.9301
# Epoch 26/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0778 - accuracy: 0.9698 - val_loss: 0.2765 - val_accuracy: 0.9301
# Epoch 27/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0761 - accuracy: 0.9708 - val_loss: 0.2868 - val_accuracy: 0.9295
# Epoch 28/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0748 - accuracy: 0.9714 - val_loss: 0.2759 - val_accuracy: 0.9320
# Epoch 29/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0709 - accuracy: 0.9729 - val_loss: 0.2827 - val_accuracy: 0.9291
# Epoch 30/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0719 - accuracy: 0.9726 - val_loss: 0.2954 - val_accuracy: 0.9312
# Epoch 31/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0710 - accuracy: 0.9725 - val_loss: 0.2980 - val_accuracy: 0.9321
# Epoch 32/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0650 - accuracy: 0.9743 - val_loss: 0.2972 - val_accuracy: 0.9304
# Epoch 33/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0648 - accuracy: 0.9747 - val_loss: 0.3084 - val_accuracy: 0.9306
# Epoch 34/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0656 - accuracy: 0.9745 - val_loss: 0.3020 - val_accuracy: 0.9342
# Epoch 35/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0646 - accuracy: 0.9753 - val_loss: 0.3039 - val_accuracy: 0.9295
# Epoch 36/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0635 - accuracy: 0.9754 - val_loss: 0.2899 - val_accuracy: 0.9251
# Epoch 37/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0612 - accuracy: 0.9769 - val_loss: 0.3192 - val_accuracy: 0.9304
# Epoch 38/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0617 - accuracy: 0.9765 - val_loss: 0.3010 - val_accuracy: 0.9288
# Epoch 39/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0598 - accuracy: 0.9773 - val_loss: 0.2983 - val_accuracy: 0.9291
# Epoch 40/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0567 - accuracy: 0.9781 - val_loss: 0.3472 - val_accuracy: 0.9289
# Epoch 41/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0578 - accuracy: 0.9770 - val_loss: 0.3178 - val_accuracy: 0.9285
# Epoch 42/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0579 - accuracy: 0.9775 - val_loss: 0.3020 - val_accuracy: 0.9285
# Epoch 43/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0557 - accuracy: 0.9789 - val_loss: 0.3292 - val_accuracy: 0.9291
# Epoch 44/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0555 - accuracy: 0.9791 - val_loss: 0.3228 - val_accuracy: 0.9309
# Epoch 45/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0511 - accuracy: 0.9811 - val_loss: 0.3370 - val_accuracy: 0.9298
# Epoch 46/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0540 - accuracy: 0.9792 - val_loss: 0.3186 - val_accuracy: 0.9326
# Epoch 47/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0519 - accuracy: 0.9800 - val_loss: 0.3317 - val_accuracy: 0.9298
# Epoch 48/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0525 - accuracy: 0.9800 - val_loss: 0.3559 - val_accuracy: 0.9292
# Epoch 49/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0524 - accuracy: 0.9801 - val_loss: 0.3312 - val_accuracy: 0.9285
# Epoch 50/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0515 - accuracy: 0.9804 - val_loss: 0.3447 - val_accuracy: 0.9315
# Epoch 51/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0497 - accuracy: 0.9813 - val_loss: 0.3660 - val_accuracy: 0.9286
# Epoch 52/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0505 - accuracy: 0.9804 - val_loss: 0.3383 - val_accuracy: 0.9309
# Epoch 53/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0495 - accuracy: 0.9810 - val_loss: 0.3513 - val_accuracy: 0.9305
# Epoch 54/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0477 - accuracy: 0.9816 - val_loss: 0.3482 - val_accuracy: 0.9287
# Epoch 55/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0495 - accuracy: 0.9815 - val_loss: 0.3633 - val_accuracy: 0.9291
# Epoch 56/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0475 - accuracy: 0.9822 - val_loss: 0.3510 - val_accuracy: 0.9297
# Epoch 57/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0462 - accuracy: 0.9820 - val_loss: 0.3482 - val_accuracy: 0.9305
# Epoch 58/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0444 - accuracy: 0.9831 - val_loss: 0.3798 - val_accuracy: 0.9288
# Epoch 59/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0455 - accuracy: 0.9820 - val_loss: 0.3607 - val_accuracy: 0.9307
# Epoch 60/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0456 - accuracy: 0.9827 - val_loss: 0.3764 - val_accuracy: 0.9312
# Epoch 61/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0459 - accuracy: 0.9823 - val_loss: 0.4001 - val_accuracy: 0.9301
# Epoch 62/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0436 - accuracy: 0.9832 - val_loss: 0.3718 - val_accuracy: 0.9333
# Epoch 63/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0442 - accuracy: 0.9832 - val_loss: 0.4037 - val_accuracy: 0.9312
# Epoch 64/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0429 - accuracy: 0.9837 - val_loss: 0.3768 - val_accuracy: 0.9302
# Epoch 65/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0425 - accuracy: 0.9839 - val_loss: 0.3723 - val_accuracy: 0.9330
# Epoch 66/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0432 - accuracy: 0.9840 - val_loss: 0.3733 - val_accuracy: 0.9311
# Epoch 67/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0443 - accuracy: 0.9835 - val_loss: 0.3951 - val_accuracy: 0.9302
# Epoch 68/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0418 - accuracy: 0.9839 - val_loss: 0.3601 - val_accuracy: 0.9315
# Epoch 69/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0419 - accuracy: 0.9844 - val_loss: 0.4052 - val_accuracy: 0.9314
# Epoch 70/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0443 - accuracy: 0.9834 - val_loss: 0.3755 - val_accuracy: 0.9306
# Epoch 71/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0429 - accuracy: 0.9836 - val_loss: 0.3765 - val_accuracy: 0.9316
# Epoch 72/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0432 - accuracy: 0.9835 - val_loss: 0.3590 - val_accuracy: 0.9328
# Epoch 73/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0397 - accuracy: 0.9853 - val_loss: 0.3818 - val_accuracy: 0.9298
# Epoch 74/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0413 - accuracy: 0.9844 - val_loss: 0.3903 - val_accuracy: 0.9326
# Epoch 75/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0423 - accuracy: 0.9850 - val_loss: 0.3990 - val_accuracy: 0.9313
# Epoch 76/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0397 - accuracy: 0.9855 - val_loss: 0.4065 - val_accuracy: 0.9313
# Epoch 77/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0378 - accuracy: 0.9856 - val_loss: 0.3931 - val_accuracy: 0.9326
# Epoch 78/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0396 - accuracy: 0.9847 - val_loss: 0.4058 - val_accuracy: 0.9327
# Epoch 79/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0408 - accuracy: 0.9850 - val_loss: 0.3712 - val_accuracy: 0.9303
# Epoch 80/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0384 - accuracy: 0.9855 - val_loss: 0.3716 - val_accuracy: 0.9306
# Epoch 81/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0388 - accuracy: 0.9855 - val_loss: 0.4121 - val_accuracy: 0.9325
# Epoch 82/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0382 - accuracy: 0.9852 - val_loss: 0.4021 - val_accuracy: 0.9320
# Epoch 83/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0388 - accuracy: 0.9857 - val_loss: 0.3909 - val_accuracy: 0.9317
# Epoch 84/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0385 - accuracy: 0.9854 - val_loss: 0.3905 - val_accuracy: 0.9313
# Epoch 85/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0404 - accuracy: 0.9851 - val_loss: 0.3937 - val_accuracy: 0.9304
# Epoch 86/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0358 - accuracy: 0.9867 - val_loss: 0.4061 - val_accuracy: 0.9353
# Epoch 87/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0399 - accuracy: 0.9856 - val_loss: 0.4142 - val_accuracy: 0.9335
# Epoch 88/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0383 - accuracy: 0.9855 - val_loss: 0.4067 - val_accuracy: 0.9322
# Epoch 89/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0366 - accuracy: 0.9862 - val_loss: 0.4322 - val_accuracy: 0.9333
# Epoch 90/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0376 - accuracy: 0.9863 - val_loss: 0.4028 - val_accuracy: 0.9322
# Epoch 91/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0335 - accuracy: 0.9869 - val_loss: 0.4248 - val_accuracy: 0.9302
# Epoch 92/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0366 - accuracy: 0.9866 - val_loss: 0.4245 - val_accuracy: 0.9355
# Epoch 93/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0347 - accuracy: 0.9874 - val_loss: 0.4273 - val_accuracy: 0.9307
# Epoch 94/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0342 - accuracy: 0.9873 - val_loss: 0.4060 - val_accuracy: 0.9335
# Epoch 95/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0351 - accuracy: 0.9868 - val_loss: 0.4098 - val_accuracy: 0.9296
# Epoch 96/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0370 - accuracy: 0.9864 - val_loss: 0.4139 - val_accuracy: 0.9316
# Epoch 97/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0342 - accuracy: 0.9867 - val_loss: 0.4044 - val_accuracy: 0.9289
# Epoch 98/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0368 - accuracy: 0.9865 - val_loss: 0.4017 - val_accuracy: 0.9312
# Epoch 99/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0355 - accuracy: 0.9864 - val_loss: 0.4538 - val_accuracy: 0.9329
# Epoch 100/100
# 469/469 [==============================] - 4s 9ms/step - loss: 0.0352 - accuracy: 0.9872 - val_loss: 0.4245 - val_accuracy: 0.9311

# %%
cnn.evaluate(xt, yt)
# Out:
# 313/313 [==============================] - 1s 3ms/step - loss: 0.4245 - accuracy: 0.9311
# [0.42454105615615845, 0.9311000108718872]
